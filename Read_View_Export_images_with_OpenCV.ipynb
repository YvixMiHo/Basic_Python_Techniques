# %% [markdown]
# <a href="https://colab.research.google.com/github/YvixMiHo/Basic_Python_Techniques/blob/main/Read_View_Export_images_with_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Read In Images into OpenCV
#
# Render Images with MATPLOTLIB
#
# Export Images From OpenCCV

# %% [markdown]
# #1. Import Dependencies

# %%
import cv2
import os
from matplotlib import pyplot as plt

# %% [markdown]
# ##1.a Helper functions

# %%
def upload_files():
    from google.colab import files
    uploaded = files.upload()
    for k,v in uploaded.items():
      open(k, 'wb').write(v)
    return list(uploaded.keys())

# %% [markdown]
# #2. Read in Image

# %%
img_path = upload_files()
# Out:
#      <input type="file" id="files-6535318e-afd9-49d7-a9f4-9ffa8465d073" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6535318e-afd9-49d7-a9f4-9ffa8465d073">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AoTS4p2KeyVisual.jpg to AoTS4p2KeyVisual (1).jpg

# %%
img = cv2.imread(img_path[0])
height, width, channels = img.shape

# %% [markdown]
# #3. Render Images

# %%
plt.imshow(img)

# %%
recolor_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(recolor_img)

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_img)

# %% [markdown]
# #4. Write out Image

# %%
cv2.imwrite('grayimage.jpg',gray_img)
# Out:
# True

# %%
output_path = os.path.join('data','Pictures','OutputGray.jpg')
output_path
# Out:
# 'data/Pictures/OutputGray.jpg'

# %%
cv2.imwrite(output_path, gray_img)
# Out:
# False
